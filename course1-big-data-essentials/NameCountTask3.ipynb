# %% [markdown]
# # Hadoop Streaming assignment 3: Name Count

# %%
# %%writefile mapper.py


import sys
import re

from imp import reload
if sys.version[0] == '2':
    reload(sys)
    sys.setdefaultencoding("utf-8") # required to convert to unicode

def read_stopwords(file_path): #Read in stop words file
    return set(word.strip().lower() for word in open(file_path))

# All conditions must be met
# 1. The first character is not a digit (other characters can be digits).
# 2. The first character is uppercase, all the other characters that are letters are lowercase.

def is_name(word):
    if len(word) < 2:
        return False
    elif (word[0].isalpha() and word[0].isupper() and word[1:].islower()):
        return True
    else:
        return False

#read in stop words
stopwords = read_stopwords("stop_words_en.txt")

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        print("Error in mapper.py", e)
        continue

    text = re.sub("^\W+|\W+$", "", text, flags=re.UNICODE)
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    
    for word in words:
        if word.lower() not in stopwords: #First filter out stop words
            name_flag = int(is_name(word))
            print ("%s\t%d\t%d" % (word.lower(), name_flag, 1))
# Out:
# Overwriting mapper.py

# %% [markdown]
# ## Step 2. Create the reducer.
#
# Create the reducer, which will accumulate the information after the mapper step. You may implement the combiner if you want. It can be useful from optimizing and speed up your computations (see the lectures from the Week 2 for more details).

# %%
# %%writefile reducer.py

# Your code for reducer here.
import sys
from imp import reload
if sys.version[0] == '2':
    reload(sys)
    sys.setdefaultencoding("utf-8") # required to convert to unicode

current_key = None
name_total = 0
word_total = 0

for line in sys.stdin:
    try:
        key, name_count, word_count = line.strip().split('\t', 2)
        name_count = int(name_count)
        word_count = int(word_count)
    except ValueError as e:
        print("error in reducer.py", e)
        continue
    
    if current_key != key:
        if current_key:
            print ("%s\t%d\t%d" % (current_key, name_total, word_total))
       
        name_total = 0
        word_total = 0
        current_key = key
        
    name_total += name_count
    word_total += word_count
    
if current_key:
    print ("%s\t%d\t%d" % (current_key, name_total, word_total))
# Out:
# Overwriting reducer.py

# %%
# %%writefile mapper2.py

# Your code for reducer here.
import sys
from imp import reload
if sys.version[0] == '2':
    reload(sys)
    sys.setdefaultencoding("utf-8") # required to convert to unicode

current_key = None
name_total = 0
word_total = 0

for line in sys.stdin:
    try:
        key, name_count, word_count = line.strip().split('\t', 2)
        name_count = int(name_count)
        word_count = int(word_count)
    except ValueError as e:
        print("error in mapper2.py", e)
        continue
    
    if current_key != key:
        if current_key:
            print ("%d\t%d\t%s" % (name_total, word_total, current_key))
       
        name_total = 0
        word_total = 0
        current_key = key
        
    name_total += name_count
    word_total += word_count
    
if current_key:
    print ("%d\t%d\t%s" % (name_total, word_total, current_key))
# Out:
# Overwriting mapper2.py

# %%
# %%writefile reducer2.py

# Your code for reducer here.
import sys
from imp import reload
if sys.version[0] == '2':
    reload(sys)
    sys.setdefaultencoding("utf-8") # required to convert to unicode


current_key = None
name_total = 0
word_total = 0

for line in sys.stdin:
    try:
        name_count, word_count, key = line.strip().split('\t', 2)
        name_count = int(name_count)
        word_count = int(word_count)
    except ValueError as e:
        print("error in reducer2.py", e)
        continue
    
    if current_key != key:
        if current_key and (float(name_total) / float(word_total) >= 0.995):
            print ("%s\t%d" % (current_key, name_total))
       
        name_total = 0
        word_total = 0
        current_key = key
        
    name_total += name_count
    word_total += word_count
    
if current_key and (float(name_total) / float(word_total) >= 0.995):
    print ("%s\t%d" % (current_key, name_total))
# Out:
# Overwriting reducer2.py

# %%
# %%bash
#
# #OUT_DIR="coursera_mr_name_count_task3"$(date +"%s%6N")
# OUT_DIR_JOB1="namecount_job1_"$(date +"%s%6N")
# OUT_DIR_JOB2="namecount_job2_"$(date +"%s%6N")
# NUM_REDUCERS=8
# LOGS="stderr_logs.txt"
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Streaming NameCountTask3 Job 1" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py,/datasets/stop_words_en.txt \
#     -mapper "python mapper.py" \
#     -combiner "python reducer.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR_JOB1} > /dev/null
#
#  yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D mapreduce.job.name="Streaming NameCountTask3 Job 2" \
#     -D stream.map.output.field.separator="\t" \
#     -D mapreduce.partition.keycomparator.options="-k1,3nr" \
#     -D mapreduce.job.reduces=1 \
#     -files mapper2.py,reducer2.py \
#     -mapper "python mapper2.py" \
#     -reducer "python reducer2.py" \
#     -input ${OUT_DIR_JOB1} \
#     -output ${OUT_DIR_JOB2} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR_JOB2}/part-00000 | head -5 | tail -1
# # Code for obtaining the results
# #hdfs dfs -cat ${OUT_DIR_2}/part-00000 | sed -n "5p;8q"
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_JOB1} > /dev/null
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_JOB2} > /dev/null
#
# #Not sure if the "*" is needed or not!
# #hdfs dfs -rm -r -skipTrash ${OUT_DIR_JOB1}* > /dev/null
# #hdfs dfs -rm -r -skipTrash ${OUT_DIR_JOB2}* > /dev/null
# Out:
# french	5742
# 18/12/21 05:58:41 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/12/21 05:58:41 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/12/21 05:58:42 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/12/21 05:58:42 INFO mapreduce.JobSubmitter: number of splits:2
# 18/12/21 05:58:42 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1545365530829_0041
# 18/12/21 05:58:42 INFO impl.YarnClientImpl: Submitted application application_1545365530829_0041
# 18/12/21 05:58:42 INFO mapreduce.Job: The url to track the job: http://3bfb327c519e:8088/proxy/application_1545365530829_0041/
# 18/12/21 05:58:42 INFO mapreduce.Job: Running job: job_1545365530829_0041
# 18/12/21 05:58:47 INFO mapreduce.Job: Job job_1545365530829_0041 running in uber mode : false
# 18/12/21 05:58:47 INFO mapreduce.Job:  map 0% reduce 0%
# 18/12/21 05:59:03 INFO mapreduce.Job:  map 67% reduce 0%
# 18/12/21 05:59:08 INFO mapreduce.Job:  map 83% reduce 0%
# 18/12/21 05:59:09 INFO mapreduce.Job:  map 100% reduce 0%
# 18/12/21 05:59:13 INFO mapreduce.Job:  map 100% reduce 13%
# 18/12/21 05:59:14 INFO mapreduce.Job:  map 100% reduce 25%
# 18/12/21 05:59:15 INFO mapreduce.Job:  map 100% reduce 38%
# 18/12/21 05:59:16 INFO mapreduce.Job:  map 100% reduce 50%
# 18/12/21 05:59:17 INFO mapreduce.Job:  map 100% reduce 75%
# 18/12/21 05:59:18 INFO mapreduce.Job:  map 100% reduce 88%
# 18/12/21 05:59:19 INFO mapreduce.Job:  map 100% reduce 100%
# 18/12/21 05:59:19 INFO mapreduce.Job: Job job_1545365530829_0041 completed successfully
# 18/12/21 05:59:19 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=19405242
# 		FILE: Number of bytes written=30408855
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=6236325
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=37453
# 		Total time spent by all reduces in occupied slots (ms)=17021
# 		Total time spent by all map tasks (ms)=37453
# 		Total time spent by all reduce tasks (ms)=17021
# 		Total vcore-milliseconds taken by all map tasks=37453
# 		Total vcore-milliseconds taken by all reduce tasks=17021
# 		Total megabyte-milliseconds taken by all map tasks=38351872
# 		Total megabyte-milliseconds taken by all reduce tasks=17429504
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=6971026
# 		Map output bytes=82053428
# 		Map output materialized bytes=9669147
# 		Input split bytes=228
# 		Combine input records=6971026
# 		Combine output records=600120
# 		Reduce input groups=426241
# 		Reduce shuffle bytes=9669147
# 		Reduce input records=600120
# 		Reduce output records=426241
# 		Spilled Records=1800360
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=491
# 		CPU time spent (ms)=42380
# 		Physical memory (bytes) snapshot=2221858816
# 		Virtual memory (bytes) snapshot=20202422272
# 		Total committed heap usage (bytes)=1570242560
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=6236325
# 18/12/21 05:59:19 INFO streaming.StreamJob: Output directory: namecount_job1_1545371920755028
# 18/12/21 05:59:20 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/12/21 05:59:20 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/12/21 05:59:21 INFO mapred.FileInputFormat: Total input files to process : 8
# 18/12/21 05:59:21 INFO mapreduce.JobSubmitter: number of splits:8
# 18/12/21 05:59:21 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1545365530829_0042
# 18/12/21 05:59:21 INFO impl.YarnClientImpl: Submitted application application_1545365530829_0042
# 18/12/21 05:59:21 INFO mapreduce.Job: The url to track the job: http://3bfb327c519e:8088/proxy/application_1545365530829_0042/
# 18/12/21 05:59:21 INFO mapreduce.Job: Running job: job_1545365530829_0042
# 18/12/21 05:59:29 INFO mapreduce.Job: Job job_1545365530829_0042 running in uber mode : false
# 18/12/21 05:59:29 INFO mapreduce.Job:  map 0% reduce 0%
# 18/12/21 05:59:33 INFO mapreduce.Job:  map 25% reduce 0%
# 18/12/21 05:59:34 INFO mapreduce.Job:  map 75% reduce 0%
# 18/12/21 05:59:37 INFO mapreduce.Job:  map 100% reduce 0%
# 18/12/21 05:59:39 INFO mapreduce.Job:  map 100% reduce 100%
# 18/12/21 05:59:39 INFO mapreduce.Job: Job job_1545365530829_0042 completed successfully
# 18/12/21 05:59:39 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=7514222
# 		FILE: Number of bytes written=16288953
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=6237349
# 		HDFS: Number of bytes written=1506528
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=8
# 		Launched reduce tasks=1
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=20340
# 		Total time spent by all reduces in occupied slots (ms)=3089
# 		Total time spent by all map tasks (ms)=20340
# 		Total time spent by all reduce tasks (ms)=3089
# 		Total vcore-milliseconds taken by all map tasks=20340
# 		Total vcore-milliseconds taken by all reduce tasks=3089
# 		Total megabyte-milliseconds taken by all map tasks=20828160
# 		Total megabyte-milliseconds taken by all reduce tasks=3163136
# 	Map-Reduce Framework
# 		Map input records=426241
# 		Map output records=426241
# 		Map output bytes=6661723
# 		Map output materialized bytes=7514264
# 		Input split bytes=1024
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=426232
# 		Reduce shuffle bytes=7514264
# 		Reduce input records=426241
# 		Reduce output records=135112
# 		Spilled Records=852482
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=671
# 		CPU time spent (ms)=15450
# 		Physical memory (bytes) snapshot=2535145472
# 		Virtual memory (bytes) snapshot=18110251008
# 		Total committed heap usage (bytes)=1747976192
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=6236325
# 	File Output Format Counters
# 		Bytes Written=1506528
# 18/12/21 05:59:39 INFO streaming.StreamJob: Output directory: namecount_job2_1545371920756861
# cat: Unable to write to output stream.
